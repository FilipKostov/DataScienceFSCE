# %%
# !gdown 1CkUp_wtuauTNL9aOW-K52jDlTXqD4KWS
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1CkUp_wtuauTNL9aOW-K52jDlTXqD4KWS
# To: /content/diabetes.csv
# 100% 23.8k/23.8k [00:00<00:00, 59.8MB/s]

# %%
import pandas as pd
import sklearn
df = pd.read_csv('/content/drive/MyDrive/Copy of airline_passenger_satisfaction.csv')

# %%
df.columns
# Out:
# Index(['id', 'Gender', 'Customer Type', 'Age', 'Type of Travel', 'Class',
#        'Flight Distance', 'Inflight wifi service',
#        'Departure/Arrival time convenient', 'Ease of Online booking',
#        'Gate location', 'Food and drink', 'Online boarding', 'Seat comfort',
#        'Inflight entertainment', 'On-board service', 'Leg room service',
#        'Baggage handling', 'Checkin service', 'Inflight service',
#        'Cleanliness', 'Departure Delay in Minutes', 'Arrival Delay in Minutes',
#        'satisfaction'],
#       dtype='object')

# %%
df.info()
df['Gender'].value_counts()
df['Gender'].value_counts().plot.bar()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 129880 entries, 0 to 129879
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 129880 non-null  int64
#  1   Gender                             129876 non-null  object
#  2   Customer Type                      129860 non-null  object
#  3   Age                                129863 non-null  float64
#  4   Type of Travel                     129846 non-null  object
#  5   Class                              129862 non-null  object
#  6   Flight Distance                    129852 non-null  float64
#  7   Inflight wifi service              129871 non-null  float64
#  8   Departure/Arrival time convenient  129854 non-null  float64
#  9   Ease of Online booking             129866 non-null  float64
#  10  Gate location                      129865 non-null  float64
# ...

# %%
perc_isnull=df.isnull().sum() / len(df) * 100
perc_isnull
# Out:
# id                                   0.000000
# Gender                               0.003080
# Customer Type                        0.015399
# Age                                  0.013089
# Type of Travel                       0.026178
# Class                                0.013859
# Flight Distance                      0.021558
# Inflight wifi service                0.006929
# Departure/Arrival time convenient    0.020018
# Ease of Online booking               0.010779
# Gate location                        0.011549
# Food and drink                       0.016169
# Online boarding                      0.011549
# Seat comfort                         0.085464
# Inflight entertainment               0.007699
# On-board service                     0.007699
# Leg room service                     0.034647
# Baggage handling                     0.010779
# Checkin service                      0.020018
# Inflight service                     0.007699
# ...

# %%
import missingno as msngo
msngo.bar(df)
msngo.heatmap(df)
msngo.dendrogram(df)
msngo.matrix(df)
msngo.matrix(df.sort_values('Gender'))
# Out:
# <Axes: >

# %%
from sklearn.impute import SimpleImputer
df_copy=df.copy()
df_copy.iloc[:,:]
df_copy.dropna(subset=['satisfaction'], how='any', inplace=True)
df_copy.Age.isnull().sum()
imp=SimpleImputer(strategy='most_frequent', fill_value=0)
df_copy.iloc[:,:]=imp.fit_transform(df_copy)
df_copy.isnull().sum()
# Out:
# id                                   0
# Gender                               0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Inflight wifi service                0
# Departure/Arrival time convenient    0
# Ease of Online booking               0
# Gate location                        0
# Food and drink                       0
# Online boarding                      0
# Seat comfort                         0
# Inflight entertainment               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Inflight service                     0
# Cleanliness                          0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# satisfaction                         0
# dtype: int64

# %%
df_copy.to_csv('/content/drive/MyDrive/Copy of airline_passenger_satisfaction_fixed.csv')
df_copy
# Out:
#             id  Gender   Customer Type   Age   Type of Travel     Class  \
# 0        70172    Male  Loyal Customer  13.0  Personal Travel  Eco Plus
# 1         5047    Male        Customer  25.0  Business travel  Business
# 2       110028  Female  Loyal Customer  26.0  Business travel  Business
# 3        24026  Female  Loyal Customer  25.0  Business travel  Business
# 4       119299    Male  Loyal Customer  61.0  Business travel  Business
# ...        ...     ...             ...   ...              ...       ...
# 129875   78463    Male        Customer  34.0  Business travel  Business
# 129876   71167    Male  Loyal Customer  23.0  Business travel  Business
# 129877   37675  Female  Loyal Customer  17.0  Personal Travel       Eco
# 129878   90086    Male  Loyal Customer  14.0  Business travel  Business
# 129879   34799  Female  Loyal Customer  42.0  Personal Travel       Eco
#
#         Flight Distance  Inflight wifi service  \
# 0                 460.0                    3.0
# ...

# %%
df_copy.head()
# Out:
#        id  Gender   Customer Type   Age   Type of Travel     Class  \
# 0   70172    Male  Loyal Customer  13.0  Personal Travel  Eco Plus
# 1    5047    Male        Customer  25.0  Business travel  Business
# 2  110028  Female  Loyal Customer  26.0  Business travel  Business
# 3   24026  Female  Loyal Customer  25.0  Business travel  Business
# 4  119299    Male  Loyal Customer  61.0  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0            460.0                    3.0                                4.0
# 1            235.0                    3.0                                2.0
# 2           1142.0                    2.0                                2.0
# 3            562.0                    2.0                                5.0
# 4            214.0                    3.0                                3.0
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
from sklearn.impute import KNNImputer
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(df_copy.iloc[:,:-1], df_copy['satisfaction'], test_size=0.2)
X_train
Y_train
# Out:
# 116133                  satisfied
# 109987    neutral or dissatisfied
# 84421                   satisfied
# 92683     neutral or dissatisfied
# 53538     neutral or dissatisfied
#                    ...
# 26206                   satisfied
# 17195     neutral or dissatisfied
# 1642                    satisfied
# 80255                   satisfied
# 109498                  satisfied
# Name: satisfaction, Length: 103904, dtype: object

# %%
lista = ['Gender', 'Customer Type', 'Type of Travel', 'Class']
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
encoder = LabelEncoder()

for i in lista:
  df[i] = encoder.fit_transform(df[i])

# %%
from sklearn.neighbors import KNeighborsClassifier
cl=KNeighborsClassifier(n_neighbors=2)
cl.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)
